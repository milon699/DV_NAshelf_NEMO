# %%
#Import Packages

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np 
import math
import matplotlib.font_manager
import cmocean as cmo
from tqdm import tqdm
import cartopy.crs as ccrs
import dask
import os

os.chdir('/home/milon.miah/Documents/Scripts')
from worldmap import WorldMap
from calc import *
os.chdir('/home/milon.miah/Documents')

# %%
#Split large chunks (from obtained warning)
dask.config.set({"array.slicing.split_large_chunks": True})

# %%
#Load data from vortex directory
vortex_path = '/vortex/clidex/data/NEMO/VIKING20X/hydrography_daily_upper200m/'
fname_prefix = '1_VIKING20X.L46-KFS003_1d_'
fname_suffix = '_45W_80W_30N_57N_upper200m.nc'
ds_temp = xr.open_mfdataset(vortex_path + fname_prefix + '*_votemper' + fname_suffix)

# %%
#Load spatial data of defined boxes
ds_masks = xr.open_dataset('/vortex/clidex/data/NEMO/VIKING20X/ecomasks_viking.nc')

#String list of masks 
masks = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'Eastern GoM', 'Eastern SS', 'Georges Bank', 'Labrador Shelf1',
         'Labrador Shelf2', 'Labrador Shelf3', 'NFL Shelf', 'Northern GSL', 'Northern MAB', 'Northern NFL Shelf',
         'Southern GSL', 'Southern MAB', 'Western GoM', 'Western SS']

#Convert to float32 array to save memory
for i in range(len(masks)):
    ds_masks[masks[i]] = xr.DataArray(data = np.float32(ds_masks[masks[i]]), dims = ['y', 'x'])

# %%
#Cut off data for each mask
ds_temp_masks = {}
for i in tqdm(range(len(masks))):
    ds_temp_masks[masks[i]] = ds_temp['votemper'].where(np.isnan(ds_masks[masks[i]]) != True, drop = True)
    
    #Cut off shelf itself (0.0 to nan)
    ds_temp_masks[masks[i]] = ds_temp_masks[masks[i]].where(ds_temp_masks[masks[i]] != 0)
    
    ds_temp_masks[masks[i]].name = 'votemper'

    #Form merged Dataset
    #if i == 0:
    #    ds_temp_tot = ds_temp_masks[masks[i]]
    #else:
    #    ds_temp_tot = xr.merge([ds_temp_tot, ds_temp_masks[masks[i]]])
    
    #Save temperature data of every mask in separate netCDF file for later use
    #Cut off nan values to decrease data size

    ds_temp_masks[masks[i]].to_netcdf('/mnt/data/Temp_Masks/Daily/temp_d_' + masks[i] + '.nc')
    print(ds_temp_masks[masks[i]].nbytes/1e9)
# Out:
#   0%|                                                                                                                                                                                  | 0/22 [00:41<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 19>()
#      11     #Form merged Dataset
#      12     #if i == 0:
#      13     #    ds_temp_tot = ds_temp_masks[masks[i]]
#    (...)
#      17 #Save temperature data of every mask in separate netCDF file for later use
#      18 #Cut off nan values to decrease data size
#      19 for i in tqdm(range(len(masks))):
# ---> 20     ds_temp_masks[masks[i]].to_netcdf('/mnt/data/Temp_Masks/Daily/temp_d_' + masks[i] + '.nc')
#      21     print(ds_temp_masks[masks[i]].nbytes/1e9)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py:2839, in DataArray.to_netcdf(self, *args, **kwargs)
#    2835 else:
#    2836     # No problems with the name - so we're fine!
#    2837     dataset = self.to_dataset()
# -> 2839 return dataset.to_netcdf(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:1902, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1899     encoding = {}
#    1900 from ..backends.api import to_netcdf
# -> 1902 return to_netcdf(
#    1903     self,
#    1904     path,
#    1905     mode,
#    1906     format=format,
#    1907     group=group,
#    1908     engine=engine,
#    1909     encoding=encoding,
#    1910     unlimited_dims=unlimited_dims,
#    1911     compute=compute,
#    1912     invalid_netcdf=invalid_netcdf,
#    1913 )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/backends/api.py:1081, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1078 if multifile:
#    1079     return writer, store
# -> 1081 writes = writer.sync(compute=compute)
#    1083 if path_or_file is None:
#    1084     store.sync()
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/backends/common.py:166, in ArrayWriter.sync(self, compute)
#     160 import dask.array as da
#     162 # TODO: consider wrapping targets with dask.delayed, if this makes
#     163 # for any discernable difference in perforance, e.g.,
#     164 # targets = [dask.delayed(t) for t in self.targets]
# --> 166 delayed_store = da.store(
#     167     self.sources,
#     168     self.targets,
#     169     lock=self.lock,
#     170     compute=compute,
#     171     flush=True,
#     172     regions=self.regions,
#     173 )
#     174 self.sources = []
#     175 self.targets = []
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py:1184, in store(***failed resolving arguments***)
#    1182 elif compute:
#    1183     store_dsk = HighLevelGraph(layers, dependencies)
# -> 1184     compute_as_if_collection(Array, store_dsk, map_keys, **kwargs)
#    1185     return None
#    1187 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:318, in compute_as_if_collection(cls, dsk, keys, scheduler, get, **kwargs)
#     314 """Compute a graph as if it were of type cls.
#     315
#     316 Allows for applying the same optimizations and default scheduler."""
#     317 schedule = get_scheduler(scheduler=scheduler, cls=cls, get=get)
# --> 318 dsk2 = optimization_function(cls)(dsk, keys, **kwargs)
#     319 return schedule(dsk2, keys, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/array/optimization.py:50, in optimize(dsk, keys, fuse_keys, fast_functions, inline_functions_fast_functions, rename_fused_keys, **kwargs)
#      48 dsk = optimize_blockwise(dsk, keys=keys)
#      49 dsk = fuse_roots(dsk, keys=keys)
# ---> 50 dsk = dsk.cull(set(keys))
#      52 # Perform low-level fusion unless the user has
#      53 # specified False explicitly.
#      54 if config.get("optimization.fuse.active") is False:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/highlevelgraph.py:954, in HighLevelGraph.cull(self, keys)
#     952 for d in culled_deps.values():
#     953     external_deps |= d
# --> 954 external_deps -= culled_layer.get_output_keys()
#     955 keys_set |= external_deps
#     957 # Save the culled layer and its key dependencies
#
# File ~/miniconda3/lib/python3.9/_collections_abc.py:609, in Set.__rsub__(self, other)
#     607         return NotImplemented
#     608     other = self._from_iterable(other)
# --> 609 return self._from_iterable(value for value in other
#     610                            if value not in self)
#
# File ~/miniconda3/lib/python3.9/_collections_abc.py:820, in KeysView._from_iterable(cls, it)
#     818 @classmethod
#     819 def _from_iterable(cls, it):
# --> 820     return set(it)
#
# File ~/miniconda3/lib/python3.9/_collections_abc.py:609, in <genexpr>(.0)
#     607         return NotImplemented
#     608     other = self._from_iterable(other)
# --> 609 return self._from_iterable(value for value in other
#     610                            if value not in self)
#
# KeyboardInterrupt:
