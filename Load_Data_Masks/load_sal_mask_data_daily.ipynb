# %%
#Import Packages

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np 
import math
import matplotlib.font_manager
import cmocean as cmo
from tqdm import tqdm
import cartopy.crs as ccrs
import dask
import os

os.chdir('/home/milon.miah/Documents/Scripts')
from worldmap import WorldMap
from calc import *
os.chdir('/home/milon.miah/Documents')

# %%
#Split large chunks (from obtained warning)
dask.config.set({"array.slicing.split_large_chunks": True})

# %%
#Load data from vortex directory
vortex_path = '/vortex/clidex/data/NEMO/VIKING20X/hydrography_daily_upper200m/'
fname_prefix = '1_VIKING20X.L46-KFS003_1d_'
fname_suffix = '_45W_80W_30N_57N_upper200m.nc'
ds = xr.open_mfdataset(vortex_path + fname_prefix + '*_vosaline' + fname_suffix)

# %%
#Load spatial data of defined boxes
ds_masks = xr.open_dataset('/vortex/clidex/data/NEMO/VIKING20X/ecomasks_viking.nc')

#String list of masks 
masks = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'Eastern GoM', 'Eastern SS', 'Georges Bank', 'Labrador Shelf1',
         'Labrador Shelf2', 'Labrador Shelf3', 'NFL Shelf', 'Northern GSL', 'Northern MAB', 'Northern NFL Shelf',
         'Southern GSL', 'Southern MAB', 'Western GoM', 'Western SS']

#Convert to float32 array to save memory
for i in range(len(masks)):
    ds_masks[masks[i]] = xr.DataArray(data = np.float32(ds_masks[masks[i]]), dims = ['y', 'x'])

# %%
#Cut off data for each mask
ds_sal_masks = {}
for i in range(len(masks)):
    ds_sal_masks[masks[i]] = ds['vosaline'].where(np.isnan(ds_masks[masks[i]]) != True, drop = True)
    ds_sal_masks[masks[i]].name = 'vosaline'

    #Form merged Dataset
    #if i == 0:
    #    ds_sal_tot = ds_sal_masks[masks[i]]
    #else:
    #    ds_sal_tot = xr.merge([ds_sal_tot, ds_sal_masks[masks[i]]])
    
#Save temperature data of every mask in separate netCDF file for later use
#Cut off nan values to decrease data size
for i in tqdm(range(len(masks))):
    ds_sal_masks[masks[i]].to_netcdf('/mnt/data/Sal_Masks/Daily/sal_d_' + masks[i] + '.nc')
# Out:
#   0%|                                                                                                                                                                                                                                                                                          | 0/22 [06:52<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 16>()
#       8     #Form merged Dataset
#       9     #if i == 0:
#      10     #    ds_temp_tot = ds_temp_masks[masks[i]]
#    (...)
#      14 #Save temperature data of every mask in separate netCDF file for later use
#      15 #Cut off nan values to decrease data size
#      16 for i in tqdm(range(len(masks))):
# ---> 17     ds_sal_masks[masks[i]].to_netcdf('/mnt/data/Sal_Masks/sal_' + masks[i])
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py:2839, in DataArray.to_netcdf(self, *args, **kwargs)
#    2835 else:
#    2836     # No problems with the name - so we're fine!
#    2837     dataset = self.to_dataset()
# -> 2839 return dataset.to_netcdf(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:1902, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1899     encoding = {}
#    1900 from ..backends.api import to_netcdf
# -> 1902 return to_netcdf(
#    1903     self,
#    1904     path,
#    1905     mode,
#    1906     format=format,
#    1907     group=group,
#    1908     engine=engine,
#    1909     encoding=encoding,
#    1910     unlimited_dims=unlimited_dims,
#    1911     compute=compute,
#    1912     invalid_netcdf=invalid_netcdf,
#    1913 )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/backends/api.py:1081, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1078 if multifile:
#    1079     return writer, store
# -> 1081 writes = writer.sync(compute=compute)
#    1083 if path_or_file is None:
#    1084     store.sync()
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/backends/common.py:166, in ArrayWriter.sync(self, compute)
#     160 import dask.array as da
#     162 # TODO: consider wrapping targets with dask.delayed, if this makes
#     163 # for any discernable difference in perforance, e.g.,
#     164 # targets = [dask.delayed(t) for t in self.targets]
# --> 166 delayed_store = da.store(
#     167     self.sources,
#     168     self.targets,
#     169     lock=self.lock,
#     170     compute=compute,
#     171     flush=True,
#     172     regions=self.regions,
#     173 )
#     174 self.sources = []
#     175 self.targets = []
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py:1184, in store(***failed resolving arguments***)
#    1182 elif compute:
#    1183     store_dsk = HighLevelGraph(layers, dependencies)
# -> 1184     compute_as_if_collection(Array, store_dsk, map_keys, **kwargs)
#    1185     return None
#    1187 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:319, in compute_as_if_collection(cls, dsk, keys, scheduler, get, **kwargs)
#     317 schedule = get_scheduler(scheduler=scheduler, cls=cls, get=get)
#     318 dsk2 = optimization_function(cls)(dsk, keys, **kwargs)
# --> 319 return schedule(dsk2, keys, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py:81, in get(dsk, result, cache, num_workers, pool, **kwargs)
#      78     elif isinstance(pool, multiprocessing.pool.Pool):
#      79         pool = MultiprocessingPoolExecutor(pool)
# ---> 81 results = get_async(
#      82     pool.submit,
#      83     pool._max_workers,
#      84     dsk,
#      85     result,
#      86     cache=cache,
#      87     get_id=_thread_get_id,
#      88     pack_exception=pack_exception,
#      89     **kwargs,
#      90 )
#      92 # Cleanup pools associated to dead threads
#      93 with pools_lock:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:497, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     495 while state["waiting"] or state["ready"] or state["running"]:
#     496     fire_tasks(chunksize)
# --> 497     for key, res_info, failed in queue_get(queue).result():
#     498         if failed:
#     499             exc, tb = loads(res_info)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:134, in queue_get(q)
#     133 def queue_get(q):
# --> 134     return q.get()
#
# File ~/miniconda3/lib/python3.9/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/miniconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
